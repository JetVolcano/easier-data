# %%
import matplotlib.pyplot as plot
import numpy as np
import random
import statistics
from main import Array2D, Array1D


Array: Array2D = Array2D([1, 3, 7], [2, 5, 3])
Array.plot()
Array2: Array1D = Array1D([1, 3, 7])
Array2.plot()
Array.show()
# Out:
# c:\Users\aaron\data\main.py:61: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.figure.show()
